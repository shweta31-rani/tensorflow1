# %% [markdown]
# What is TensorFlow 2.0, and how is it different from TensorFlow 1.x2?-f
#
#
#
# ans:TensorFlow 2.0 is a major update to the open-source machine learning library TensorFlow, focusing on simplicity, ease of use, and developer productivity. It introduces significant changes compared to TensorFlow 1.x, primarily aiming to make the framework more intuitive and Pythonic.

# %% [markdown]
# How do you install TensorFlow 2.0?
#
#
# ANS:Installing TensorFlow 2.0 primarily involves using pip, the Python package installer. It is recommended to install it within a virtual environment to manage dependencies and avoid conflicts with other Python projects.-F
#
# pip install tensorflow==2.0.0

# %% [markdown]
# What is the primary function of the tf.function in TensorFlow 2.0?
#
#
#
#
# ou can use tf. function to make graphs out of your programs. It is a transformation tool that creates Python-independent dataflow graphs out of your Python code. This will help you create performant and portable models, and it is required to use SavedModel .

# %% [markdown]
# What is the purpose of the Model class in TensorFlow 2.0?
#
#
#
# ANs:o do machine learning in TensorFlow, you are likely to need to define, save, and restore a model. A model is, abstractly: A function that computes something on tensors (a forward pass) Some variables that can be updated in response to training.

# %% [markdown]
# How do you create a neural network using TensorFlow 2.0?
#
#
# ANS:
#
#  Step 1: Define the Problem and Collect Data.-F
#
#
#   Step 2: Prepare Data for Training.-F
#
#
#   Step 3: Design Neural Network Architecture.-F
#
#
#   Step 4: Initialize Parameters.-F
#
#
#   Step 5: Implement Forward Propagation.-F
#
#
#   Step 6: Define and Compute Cost Function.
#
#
#   Step 7: Training the Neural Network.

# %% [markdown]
# What is the importance of Tensor Space in TensorFlow?
#  Tensors are the fundamental data structure in TensorFlow, and they represent the flow of data through a computation graph. Tensors generalize scalars, vectors, and matrices to higher dimensions.

# %% [markdown]
# How can TensorBoard be integrated with TensorFlow 2.0?
#
# ANS:TensorBoard is integrated with TensorFlow 2.0 primarily through the tf.keras.callbacks.TensorBoard callback when using Keras, or by using tf.summary APIs for more granular control.

# %% [markdown]
# What is the purpose of TensorFlow Playground?
#
# ANS:TensorFlow Playground is an interactive, web-based tool designed to help users understand and visualize how neural networks work. Its primary purpose is to provide an intuitive and accessible platform for experimenting with various aspects of neural network architecture and training, without requiring extensive programming knowledge.

# %% [markdown]
# 9. What is Netron, and how is it useful for deep learning models.
#
# This deep neural network is trained and validated on simulated database, and tested on real scattering images. The fundamental properties of the neutron make it a pow- erful tool to investigate atomic-scale structure and dynamics of materials.

# %% [markdown]
# 10 What is the difference between TensorFlow and PyTorch?
#
#
# ANS:Pytorch was developed by facebook and tensorflow developed by google.Pytorch made using Torch library.Tensorflow was deployed on Theano which is a python library.

# %% [markdown]
# 11.How do you install PyTorch?
#
# To install PyTorch, visit the PyTorch website to get the specific installation command for your operating system, package manager (pip or conda), and desired compute platform (CPU, CUDA, or ROCm). For example, a common installation command using pip is pip install torch torchvision torchaudio for the CPU-only version, but you should always generate the command from the official PyTorch website for the most up-to-date and accurate installation.

# %% [markdown]
# 12. What is the basic structure of a PyTorch neural network?
#
# ans:he elementary data structure for representing and processing data in PyTorch is torch. Tensor, The mathematical term tensor stands for a generalization of vectors and matrices. Tensors in the form of multidimensional arrays are implemented in PyTorch.

# %% [markdown]
# 13. What is the significance of tensors in PyTorch?
#
#
# ans:In PyTorch, tensors are fundamental, multi-dimensional arrays that store data and are used for all computations within neural networks, including inputs, outputs, and model parameters. Their significance lies in enabling complex mathematical operations, allowing models to be built on hardware accelerators like GPUs, and critically supporting automatic differentiation for backpropagation by maintaining a record of operations in a directed acyclic graph.

# %% [markdown]
# 14 What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?
#
#
# Key Differences Summarized:-f
#
#
#
#    Memory Location:-f
#
#
#     torch.Tensor is in CPU memory; torch.cuda.Tensor is in GPU memory.
#     Computation Device:
#     torch.Tensor computations use the CPU; torch.cuda.Tensor computations use the GPU.
#    Performance:-f
#
#
#     torch.cuda.Tensor generally offers much faster computation for large-scale operations due to the parallel processing capabilities of GPUs, especially in deep learning.

# %% [markdown]
# 15. What is the purpose of the torch.optim module in PyTorch?
#
#
# ans:he torch.optim module in PyTorch provides a collection of optimization algorithms, known as optimizers, which are crucial for training neural networks. The primary purpose of this module is to facilitate the adjustment of a model's parameters (weights and biases) during the training process to minimize a defined loss function.

# %% [markdown]
#  16.What are some common activation functions used in neural networks?-f
#
#
#  Common activation functions include Sigmoid, which outputs values between 0 and 1; Tanh, an S-shaped function that outputs between -1 and 1; ReLU (Rectified Linear Unit), which outputs the input if positive or zero, and zero otherwise, offering computational efficiency; and Softmax, used for multi-class classification to produce probability distributions.

# %% [markdown]
# What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?
#
#
# Purpose:
# nn.Module is the general blueprint for any network component, while nn.Sequential is a specialized container for linear stacks of layers.
# Flexibility:
# nn.Module offers maximum flexibility for custom architectures, whereas nn.Sequential simplifies the definition of purely sequential networks.

# %% [markdown]
# How can you monitor training progress in TensorFlow 2.0?
#
# The best way to evaluate any change in learning is through assessment before and after the training. Conduct a pretest before and a posttest after your training and then compare the results. Considerations: The test can include a demonstration to assess skill in addition to knowledge, if needed.

# %% [markdown]
#  19.How does the Keras API fit into TensorFlow 2.0?
#
#
#  ans:Keras is integrated as the official high-level API for TensorFlow 2.0. This means that Keras functionalities are directly accessible and recommended for building and training deep learning models within the TensorFlow ecosystem.

# %% [markdown]
#  What is an example of a deep learning project that can be implemented using TensorFlow 2.0?
#
#
#  TensorFlow combines various machine learning and deep learning (or neural networking) models and algorithms, and makes them useful by way of a common interface. It enables developers to create dataflow graphs with computational nodes representing mathematical operations.

# %% [markdown]
# 21.What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
#
#
# The main advantage of using pre-trained models in TensorFlow and PyTorch is significantly reduced training time and computational resources, coupled with improved accuracy and the ability to leverage transfer learning.

# %% [markdown]
# #practical

# %%
pip install tensorflow

# %%
import tensorflow as tf


@tf.function
def add_numbers(x, y):
    return tf.add(x, y)

# Example usage
a = tf.constant(5)
b = tf.constant(3)

result = add_numbers(a, b)
print("Result:", result.numpy())
# Out:
# Result: 8

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define a simple neural network
model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10,)),  # Hidden layer with 16 neurons
    layers.Dense(1, activation='sigmoid')  # Output layer
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Summary of the model
model.summary()

# Example dummy data
import numpy as np
X = np.random.rand(100, 10)   # 100 samples, 10 features
y = np.random.randint(0, 2, size=(100, 1))  # Binary labels

# Train the model
model.fit(X, y, epochs=5, batch_size=8)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Build a simple model ---
model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# --- 2. Dummy data ---
X = np.random.rand(200, 10)   # 200 samples, 10 features
y = np.random.randint(0, 2, size=(200, 1))  # Binary labels

# --- 3. Train the model and capture history ---
history = model.fit(X, y, epochs=20, batch_size=16, validation_split=0.2, verbose=0)

# --- 4. Plot training progress ---
plt.figure(figsize=(12, 5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()

plt.show()

# %%
import torch

# Check version
print("PyTorch version:", torch.__version__)

# Check CUDA availability
print("CUDA available:", torch.cuda.is_available())

# If CUDA is available, print GPU name
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: False

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# --- 1. Define the Neural Network ---
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.hidden = nn.Linear(10, 16)   # Input layer (10 features) → Hidden layer (16 neurons)
        self.relu = nn.ReLU()
        self.output = nn.Linear(16, 1)    # Hidden layer → Output (1 neuron)

    def forward(self, x):
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)
        return torch.sigmoid(x)  # Sigmoid for binary classification

# --- 2. Initialize model, loss, optimizer ---
model = SimpleNN()
criterion = nn.BCELoss()  # Binary Cross Entropy Loss
optimizer = optim.Adam(model.parameters(), lr=0.01)

# --- 3. Dummy training data ---
X = torch.rand(100, 10)   # 100 samples, 10 features
y = torch.randint(0, 2, (100, 1)).float()  # Binary labels (0/1)

# --- 4. Training loop ---
for epoch in range(20):
    # Forward pass
    outputs = model(X)
    loss = criterion(outputs, y)

    # Backward pass & optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch+1) % 5 == 0:
        print(f"Epoch [{epoch+1}/20], Loss: {loss.item():.4f}")
# Out:
# Epoch [5/20], Loss: 0.6843
# Epoch [10/20], Loss: 0.6798
# Epoch [15/20], Loss: 0.6735
# Epoch [20/20], Loss: 0.6657

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Dummy neural network
model = nn.Sequential(
    nn.Linear(10, 16),   # Input → Hidden
    nn.ReLU(),
    nn.Linear(16, 1),    # Hidden → Output
    nn.Sigmoid()
)

# --- Loss Function ---
criterion = nn.BCELoss()  # Binary Cross Entropy Loss (for binary classification)

# --- Optimizer ---
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer

# %%
import torch

# Example: Mean Absolute Percentage Error (MAPE)
def custom_mape_loss(y_pred, y_true):
    epsilon = 1e-7  # to avoid division by zero
    return torch.mean(torch.abs((y_true - y_pred) / (y_true + epsilon))) * 100

# Example usage
y_true = torch.tensor([3.0, 5.0, 2.5])
y_pred = torch.tensor([2.5, 5.0, 2.0])

loss = custom_mape_loss(y_pred, y_true)
print("Custom Loss:", loss.item())
# Out:
# Custom Loss: 12.222222328186035

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# --- Build a simple model ---
model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy')

# --- Save the model ---
model.save("my_model")   # folder "my_model/" will be created

# --- Load the model ---
loaded_model = tf.keras.models.load_model("my_model")

# Verify
print("Loaded model summary:")
loaded_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3229523446.py in <cell line: 0>()
#      11
#      12 # --- Save the model ---
# ---> 13 model.save("my_model")   # folder "my_model/" will be created
#      14
#      15 # --- Load the model ---
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# ...
